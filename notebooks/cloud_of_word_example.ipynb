# %%
import pandas as pd
from text_tools import preprocessing

df=pd.read_csv("/Users/leffepierre/Documents/Ynov/ML/teaching_ML_project/en.openfoodfacts.org.products.csv",
                     sep="\t", encoding="utf-8", nrows=100000, low_memory=False)
df=preprocessing(df,"categories_en")
df
# Out:
#                                            categories_en
# 7                   groceries condiments sauces mustards
# 16                                 marzipan almond paste
# 17     meals prepared vegetables grated carrots seaso...
# 26                          pies sweet pies coconut pies
# 36     plant based foods and beverages plant based fo...
# ...                                                  ...
# 99977  plant based foods and beverages plant based fo...
# 99978    snacks sweet snacks biscuits and cakes biscuits
# 99979                                   beverages waters
# 99980  plant based foods and beverages plant based fo...
# 99985  snacks salty snacks appetizers chips and fries...
#
# [72254 rows x 1 columns]

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = ["food","and"], 
                min_font_size = 10).generate(' '.join(df['categories_en']))

import matplotlib.pyplot as plt
  
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(width = 800, height =500, 
                background_color ='white', 
                stopwords = ["food","foods","and"], 
                min_font_size = 10).generate(' '.join(df_object['categories_en']))

import matplotlib.pyplot as plt
  
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
